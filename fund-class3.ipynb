# %%
# Lesson 3 is a major step because it introduces the logic that makes programs actually “think”: conditions, for loops, while loops, range(), enumerate(), break, continue, and nested loops. Your PDF then combines all of that into a Console Study Tracker project.

# For today, do not try to complete every single exercise. Focus on the core patterns first. I would practise in this order: Conditions → for loops → range() → while loops → break/continue. Leave nested loops and the full study tracker until the basics feel comfortable.

# %%
number = int(input("Enter a number: "))

if number > 0:
    print("Positive")
elif number < 0:
    print("Negative")
else:
    print("Zero")

# %%
age = int(input("Enter your age: "))

if age < 13:
    print("Child")
elif age < 18:
    print("Teenager")
elif age < 65:
    print("Adult")
else:
    print("Senior")

# %%
# asks for a grade calculator.
score = int(input("Enter score: "))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")

# %%
language = ["Python", "Java", "c# "]
print(language[0])  # Accessing the first element
print(language[1])  # Accessing the second element
print(language[2])  # Accessing the third element

# %%
# comparison operators
print(5 > 3)   # True
print(5 < 3)   # False
print(5 == 5)  # True
print(5 != 3)  # True
print(5 >= 5)  # True
print(5 <= 3)  # False

# %%
print(1==1)  # True
print(1=="1")  # False
print("1"=="1")   # True

# %%
# and or not 
age = 16
has_ticket = True
print(age >= 18 and has_ticket)  # True
# print(True and True)   # True
# print(True and False)  # False
# print(True or False)   # True
# print(not True)        # False
# Out:
# False

# %%
# in, not in
language = ["Python", "Java", "C#"]
print("Python" in language)  # True
print("JavaScript" in language)  # False
print("Rust" not in language)  # False
print("JavaScript" not in language)  # True

# %%
# indentation if , else, elif
age = 25

if age >=9:
    print("You are a child.")
elif age <= 14:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are a child.

# %%
# Entry Control if , else, elif greater than or equal to 18 and has ticket
age = 25
has_ticket = True
if age >= 18 and has_ticket:
    print("You can enter!")
else:
    print("Entry denied!")
# Out:
# You can enter.

# %%
items = []

if items:
    print("The list contains data")
else:
    print("The list is empty")

# %%
# Dictionary Operations 
subjects = {
"Python": {"hours": 160, "teacher": "Aladdin"},
"AI": {"hours": 140, "teacher": "Haithem"}
}
print(subjects["Python"]["hours"])
print(subjects["AI"]["teacher"])
# Out:
# 160
# Haithem

# %%
# indexing and slicing
language = ["Python", "Java", "C#", "JavaScript", "Rust"]
print(language[0])  # Accessing the first element   
print(language[2:4])  # Slicing the list

# %%
# while loop
count = 0
while count < 5:
    print(count)
    count += 1  # Increment the counter

# %%
# break and continue
numbers = [ 2, 3, 4, 5]
for num in numbers:
    if num %2 != 0:
        print("found an odd number:", num)
        break  # Exit the loop when an odd number is found
# Out:
# found an odd number: 3

# %%
files = ["   File1", " File2 ", "File3  "]
for file in files:
    file = file.strip()
    print(f"Prossessing file: {file}")
# Out:
# Prossessing file: File1
# Prossessing file: File2
# Prossessing file: File3

# %%
number = int(input("Enter a number:"))
if number > 0:
    print("Positive")
elif number < 0:
        print("Negative")
else:
            print("Zero")

# %%
# Age Group Checker with if, elif, else
age = int(input("Enter your age:"))
if age < 13:
    print("Child")
elif age < 20:
        print ("Teenager")
elif age < 60:
            print("Adult")
else:
                print("Senior")
# Out:
# Senior

# %%
# comparison operators
# ==   equal to. print(10 == 5)
# !=   not equal to. print(10 != 5)
# >    greater than. print(10 > 5)
# <    less than. print(10 < 5)
# >=   greater than or equal to. print(10 >= 5)
# <=   less than or equal to. print(10 <= 5)

# %%
# Then practise and, or, and not, because Part A and Part B use them
user_name = "Python"
store_password = "1234"

user_name =input("user_name:")
password =input("store_password:")

if user_name =="Python" and password == store_password:
    print("Access granted")
else:
        print("Acess denied")
# Out:
# Access granted

# %%
# for loop and strip to remove space, lower is to text , replace is .txt to .csv
files =[" REPORT.csv", " DATA.csv", "SUMMARY.TXT  "]
for file in files:
    file = file.strip().lower().replace(".txt",".csv")
    print(f"Processing {file}")

# %%
# Enter any number to see the  table using for loop
number = int(input("Enter a number: "))

for i in range(1, 11):
    print(f"{number} x {i} = {number * i}")

# %%
# Then learn enumerate():
songs = ["Song A", "Song B", "Song C"]

for number, song in enumerate(songs, start=1):
    print(number, song)

# %%
# total   loop
total = 0

number = int(input("Enter a number, or 0 to stop: "))

while number != 0:
    total += number
    number = int(input("Enter another number, or 0 to stop: "))

print("Total:", total)

# %%
# break 
for number in range(1, 100):
    if number == 10:
        break

    print(number)

# %%
# contiune
for number in range(1, 100):
    if number == 10:
        break

    print(number)

# %%
# and means both conditions must be true.
stored_username = "sam"
stored_password = "python123"

username = input("Username: ")
password = input("Password: ")

if username == stored_username and password == stored_password:
    print("Login successful")
else:
    print("Login failed")

# %%
# truthy/falsy values and membership. 
# You do not need to spend too long here today, but understand the concept. Empty values often behave as false:

name = ""

if name:
    print("Name exists")
else:
    print("Name is empty")

# %%
numbers = []

if numbers:
    print("List contains something")
else:
    print("List is empty")

# %%
languages = ["Python", "Java", "C#"]

language = input("Enter language: ")

if language in languages:
    print("Supported")
else:
    print("Not supported")

# %%
# Loop
for item in collection:
    print(item)

# %%
names = ["Sam", "Alex", "Sara"]

for name in names:
    print(name)

# %%
numbers = [10, 20, 30, 40]

total = 0

for number in numbers:
    total = total + number

print(total)

# %%
scores = [90, 45, 72, 65, 88, 30]

passes = 0
failures = 0

for score in scores:
    if score >= 70:
        passes += 1
    else:
        failures += 1

print("Passes:", passes)
print("Failures:", failures)
